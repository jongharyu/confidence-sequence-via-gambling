# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle 

import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from collections import defaultdict

# %%
import os
import sys
# sys.path.insert(0, "..")
sys.path.append("/Users/jongha/Dropbox/src/_gambling/confidence-sequence-via-gambling") 

import pyximport
pyximport.install()

from methods.kt import CoinBettingCI, HorseRaceCI
from methods.lbup import LowerBoundStockInvestmentCI
from methods.up import StockInvestmentCI
from methods.hybrid import HybridCI
from methods.precise.co96 import PRECiSE_CO96
from methods.precise.a_co96 import PRECiSE_A_CO96
from methods.precise.r70 import PRECiSE_R70

# %%
def generate_bernoulli(t, p, seed=0):
    np.random.seed(seed)
    return (np.random.uniform(size=t) <= p).astype(int)

# %%
def generate_beta(t, betas, seed=0):
    np.random.seed(seed)
    return np.random.beta(*betas, size=t)

# %%
def generate_unif(t, seed=0):
    np.random.seed(seed)
    return np.random.rand(t)

# %% [markdown]
# # Experiments

# %%
line_configs = dict()
line_configs['CB'] = dict(c='brown', ls='solid', marker='x')
line_configs['HR'] = dict(c='m', ls='solid', marker='o')

line_configs['PRECiSE_CO96'] = dict(c='tab:pink', ls=(0, (3, 1, 1, 1)), marker='^')
line_configs['PRECiSE_A_CO96'] = dict(c='tab:green', ls=(0, (3, 1, 1, 1)), marker='^')
line_configs['PRECiSE_R70'] = dict(c='tab:blue', ls=(0, (3, 1, 1, 1)), marker='^')
line_configs['UP'] = dict(c='black', ls='-.', marker='D')
line_configs['UP_halfs'] = dict(c='black', ls='-.', marker='D')
line_configs['UP_ones'] = dict(c='tab:blue', ls='dotted', marker='x')

line_configs['LBUP1'] = dict(c='orange', ls='dotted', marker='+')
line_configs['LBUP2'] = dict(c='purple', ls='dotted', marker='+')
line_configs['LBUP3'] = dict(c='red', ls='dotted', marker='+')

line_configs['HybridUP1,50'] = dict(c='green', ls='--', marker='s', markersize=5)
line_configs['HybridUP2,50'] = dict(c='orange', ls='--', marker='s', markersize=5)
line_configs['HybridUP3,50'] = dict(c='blue', ls='--', marker='s', markersize=5)

for key in line_configs:
    line_configs[key]['markevery'] = 0.1


labels = dict()
labels['CB'] = 'CB'
labels['HR'] = 'HR'

labels['PRECiSE_CO96'] = 'PRECiSE_CO96'
labels['PRECiSE_A_CO96'] = 'PRECiSE_A_CO96'
labels['PRECiSE_R70'] = 'PRECiSE_R70'
labels['UP'] = 'UP'
labels['UP_halfs'] = 'UP(1/2,1/2)'
labels['UP_ones'] = 'UP(1,1)'

labels['LBUP1'] = r'LBUP ($n$=1)'
labels['LBUP2'] = r'LBUP ($n$=2)'
labels['LBUP3'] = r'LBUP ($n$=3)'

labels['HybridUP1,50'] = r'HybridUP ($n$=1)' #',$t_{\mathsf{UP}}=50$)'
labels['HybridUP2,50'] = r'HybridUP ($n$=2)'
labels['HybridUP3,50'] = r'HybridUP ($n$=3)'

# %%
wor = False

t = 10 ** 4
ts = np.arange(1, t + 1)

delta = 0.05
seeds = range(5)

tcut = 10 ** 4
tup = 50

# %%
import _pickle as cPickle

# %%
alg_sets = {1:[
    'UP', 
    # 'UP_ones',
    'CB', 
    'HR', 
    'PRECiSE_CO96', 
    'PRECiSE_A_CO96', 
    'PRECiSE_R70', 
    'LBUP1', 'LBUP2', 'LBUP3',],
            2: [
#     'CB', 'HR', 
    # 'UP_ones', 
    'PRECiSE_CO96', 
    'PRECiSE_A_CO96', 
#     'PRECiSE_R70', 
    'LBUP1', 'LBUP2', 'LBUP3', 
    'HybridUP1,50', 'HybridUP2,50', 'HybridUP3,50',
               ]
           }

# %%
tstart = 0

# %%
problems = {
    'bern0.25': dict(mu=0.25, title='Bern(0.25)', sampler=lambda seed: generate_bernoulli(t, p=0.25, seed=seed)),
    'beta1,3': dict(mu=0.2, title='Beta(1,3)', sampler=lambda seed: generate_beta(t, betas=[1, 3], seed=seed)),
    'beta10,30': dict(mu=0.25, title='Beta(10,30)', sampler=lambda seed: generate_beta(t, betas=[10, 30], seed=seed)),
    'bern0.5': dict(mu=0.5, title='Bern(0.5)', sampler=lambda seed: generate_bernoulli(t, p=0.5, seed=seed)),
    'beta1,1': dict(mu=0.5, title='Beta(1,1)', sampler=lambda seed: generate_beta(t, betas=[1, 1], seed=seed)),
    'beta10,10': dict(mu=0.5, title='Beta(10,10)', sampler=lambda seed: generate_beta(t, betas=[10, 10], seed=seed)),
    # 'bern0.01': dict(mu=0.01, title='Bern(0.01)', sampler=lambda seed: generate_bernoulli(t, p=0.01, seed=seed)),
    # 'unif': dict(mu=0.5, title='Unif', sampler=lambda seed: generate_unif(t, seed=seed)),
}

# %%
for kwd in problems:
    mu = problems[kwd]['mu']
    title = problems[kwd]['title']
    if not os.path.exists(f'exp-results/{kwd}_wor{int(wor)}_lower_ci.pkl'):
        lower_ci = defaultdict(lambda: np.zeros((len(seeds), t)))
        upper_ci = defaultdict(lambda: np.zeros((len(seeds), t)))
        telapsed = defaultdict(lambda: np.zeros((len(seeds), t // 100)))
        
        for j, seed in enumerate(seeds):
            np.random.seed(seed)
            xs = problems[kwd]['sampler'](seed)
            
            print(f"Seed {seed}: Naive coin betting...")
            lower_ci['CB'][j], upper_ci['CB'][j] = CoinBettingCI().construct(delta, xs[:tcut], wor=wor)

            print(f"Seed {seed}: Horse race...")
            lower_ci['HR'][j], upper_ci['HR'][j], telapsed['HR'][j] = HorseRaceCI().construct(delta, xs[:tcut], wor=wor)

            print(f"Seed {seed}: PRECiSE_CO96...")
            lower_ci['PRECiSE_CO96'][j], upper_ci['PRECiSE_CO96'][j], telapsed['PRECiSE_CO96'][j] = PRECiSE_CO96().construct(delta, xs[:tcut], wor=wor)

            try:
                print(f"Seed {seed}: PRECiSE_A_CO96...")
                lower_ci['PRECiSE_A_CO96'][j], upper_ci['PRECiSE_A_CO96'][j], telapsed['PRECiSE_A_CO96'][j] = PRECiSE_A_CO96().construct(delta, xs[:tcut], wor=wor)
            except:
                print('PRECiSE_A_CO96 encounters an error') 
            if 'bern' not in kwd:
                print(f"Seed {seed}: PRECiSE_R70...")
                lower_ci['PRECiSE_R70'][j], upper_ci['PRECiSE_R70'][j], telapsed['PRECiSE_R70'][j] = PRECiSE_R70().construct(delta, xs[:tcut], wor=wor)

                print(f"Seed {seed}: UP...")
                lower_ci['UP'][j], upper_ci['UP'][j], telapsed['UP'][j], *_ = StockInvestmentCI().construct(delta, xs[:tcut], wor=wor)
                lower_ci['UP_ones'][j], upper_ci['UP_ones'][j], telapsed['UP_ones'][j], *_ = StockInvestmentCI(betas=(1, 1)).construct(delta, xs[:tcut], wor=wor)

                print(f"Seed {seed}: LBUP...")
                lower_ci['LBUP1'][j], upper_ci['LBUP1'][j], telapsed['LBUP1'][j] = LowerBoundStockInvestmentCI(n=1).construct(delta, xs[:tcut], wor=wor, eps=1e-3)
                lower_ci['LBUP2'][j], upper_ci['LBUP2'][j], telapsed['LBUP2'][j] = LowerBoundStockInvestmentCI(n=2).construct(delta, xs[:tcut], wor=wor, eps=1e-3)
                lower_ci['LBUP3'][j], upper_ci['LBUP3'][j], telapsed['LBUP3'][j] = LowerBoundStockInvestmentCI(n=3).construct(delta, xs[:tcut], wor=wor, eps=1e-3)

                print(f"Seed {seed}: HybridUP...")
                lower_ci[f'HybridUP1,{tup}'][j], upper_ci[f'HybridUP1,{tup}'][j], telapsed[f'HybridUP1,{tup}'][j] = HybridCI(n=1, tup=tup).construct(delta, xs[:tcut], wor=wor)
                lower_ci[f'HybridUP2,{tup}'][j], upper_ci[f'HybridUP2,{tup}'][j], telapsed[f'HybridUP2,{tup}'][j] = HybridCI(n=2, tup=tup).construct(delta, xs[:tcut], wor=wor)
                lower_ci[f'HybridUP3,{tup}'][j], upper_ci[f'HybridUP3,{tup}'][j], telapsed[f'HybridUP3,{tup}'][j] = HybridCI(n=3, tup=tup).construct(delta, xs[:tcut], wor=wor)

        with open(f'exp-results/{kwd}_wor{int(wor)}_lower_ci.pkl', 'wb') as f:
            pickle.dump(dict(lower_ci), f)
        with open(f'exp-results/{kwd}_wor{int(wor)}_upper_ci.pkl', 'wb') as f:
            pickle.dump(dict(upper_ci), f)
        with open(f'exp-results/{kwd}_wor{int(wor)}_telapsed.pkl', 'wb') as f:
            pickle.dump(dict(telapsed), f)

    else:
        print(f"Warning: {f'exp-results/{kwd}_wor{int(wor)}_lower_ci.pkl'} already exists!")
        with open(fr'exp-results/{kwd}_wor{int(wor)}_lower_ci.pkl', "rb") as f:
            lower_ci = cPickle.load(f)
        with open(fr'exp-results/{kwd}_wor{int(wor)}_upper_ci.pkl', "rb") as f:
            upper_ci = cPickle.load(f)
        with open(fr'exp-results/{kwd}_wor{int(wor)}_telapsed.pkl', "rb") as f:
            telapsed = cPickle.load(f)
        if 'bern' not in kwd:
            with open(fr'exp-results/{kwd}_wor{int(wor)}_lower_ci_up.pkl', "rb") as f:
                lower_ci['UP_ones'] = cPickle.load(f)['UP_ones']
            with open(fr'exp-results/{kwd}_wor{int(wor)}_upper_ci_up.pkl', "rb") as f:
                upper_ci['UP_ones'] = cPickle.load(f)['UP_ones']
            with open(fr'exp-results/{kwd}_wor{int(wor)}_telapsed_up.pkl', "rb") as f:
                telapsed['UP_ones'] = cPickle.load(f)['UP_ones']

    try:
        upper_ci['PRECiSE_A_CO96'] = np.maximum(upper_ci['PRECiSE_A_CO96'], upper_ci['PRECiSE_CO96'])
        lower_ci['PRECiSE_A_CO96'] = np.minimum(lower_ci['PRECiSE_A_CO96'], lower_ci['PRECiSE_CO96'])
    except:
        print('PRECiSE_A_CO96 encountered an error') 
    
    # plot
    for set_id in alg_sets:
        alg_set = alg_sets[set_id]
        sizes = dict()
        for key in upper_ci:
            sizes[key] = (upper_ci[key][:tcut] - lower_ci[key][:tcut]).mean(axis=0)

        up_key = 'UP' if 'bern' not in kwd else 'HR'
        for key in upper_ci:
            if key != up_key:
                sizes[key] = np.maximum(1e-7, sizes[key] - sizes[up_key])

        fig, axes = plt.subplots(ncols=3, nrows=1, figsize=(12, 3))

        # 1) plot confidence sequences
        ax = axes[0]
        for key in alg_set:
            if key in upper_ci:
                # if key == 'PRECiSE_A_CO96' and 'bern' in kwd:
                #     pass
                # else:
                    ax.plot(ts[tstart:], lower_ci[key].mean(axis=0)[tstart:], **line_configs[key], 
                            label='HR(=UP)' if key == 'HR' and 'bern' in kwd else labels[key])
                    ax.plot(ts[tstart:], upper_ci[key].mean(axis=0)[tstart:], **line_configs[key])

        # etc
        ax.axhline(y=mu, c='k', linestyle=(0, (5, 10)))
        ax.axvline(x=tup, linestyle='dashed')
        ax.set_xscale('log')
        # ax.set_ylim([0.24, 0.26])
        # ax.set_ylim([0.2, 0.3])
        ax.set_ylim([0, 1.05])
        ax.set_xlim([1, t])

        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.spines['bottom'].set_visible(False)
        ax.spines['left'].set_visible(False)

        ax.set_xlabel(r'$t$')
        ax.set_ylabel('confidence sequences')
    #     ax.set_title(title)

        # 2) plot relative confidence sequence sizes compared to UP
        ax = axes[1]
        for key in alg_set:
            if key in upper_ci:
                if key != up_key:
    #             if 'Hybrid' not in key:
    #             if 'UP' in key:
                    # if key == 'PRECiSE_A_CO96' and 'bern' in kwd:
                    #     pass
                    # else:
                    ax.plot(ts[tstart:tcut], sizes[key][tstart:], **line_configs[key], label=labels[key])

        ax.set_xscale('log')
        ax.set_yscale('log')
        ax.axvline(x=50, linestyle='dotted')
        ax.set_ylim([1e-7, 1e0])
        ax.set_xlim([1, t])

        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.spines['bottom'].set_visible(False)
        ax.spines['left'].set_visible(False)

        ax.set_xlabel(r'$t$')
        ax.set_ylabel('width(CS) - width(UP)')
    #     ax.set_title(title)

        # 3) plot time elapsed
        ax = axes[2]

        every = 100
        tlogs = np.arange(every, t + every, every)

        for key in alg_set:
            if key in telapsed:
    #         if 'Hybrid' not in key:
    #         if 'UP' in key:
                # if key == 'PRECiSE_A_CO96' and 'bern' in kwd:
                #     pass
                # else:
                    ax.plot(tlogs, telapsed[key].mean(axis=0).cumsum(), **line_configs[key], label=labels[key])

    #     ax.axis('scaled')
        ax.set_aspect('equal')
        ax.set_xscale('log')
        ax.set_yscale('log')
        ax.set_xlim(xmin=2 * every, xmax=t)
        ax.set_ylim([5e-2, 5e2])

        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.spines['bottom'].set_visible(False)
        ax.spines['left'].set_visible(False)

        ax.set_xlabel(r'$t$')
        ax.set_ylabel('time elpased')
    #     ax.set_title(title)

        # show legends
        handles, labels_ = axes[0].get_legend_handles_labels()
        fig.legend(handles, labels_, 
                   loc='center left', 
                   bbox_to_anchor=(1., .5),
                   ncol=1,
        #            borderpad=2.5,
                   frameon=False)
        fig.tight_layout()
        # fig.subplots_adjust(left=0, wspace=0.3) 
        fig.savefig(f'figs/ex_{kwd}_set{set_id}.pdf', bbox_inches='tight')

        plt.show()

    for key in telapsed:
        cumt = telapsed[key].mean(axis=0).cumsum()
        print(key, end=': ')
        coeffs = []
        for j in range(1, 11):
            coeffs.append((np.log(cumt[-j] - cumt[0]) - np.log(cumt[-j-1] - cumt[0])) / (np.log(tlogs[-j] - tlogs[0]) - np.log(tlogs[-j-1] - tlogs[0])))
        print(np.mean(coeffs))
# Out:
# Warning: exp-results/bern0.25_wor0_lower_ci.pkl already exists!
# HR: 0.6822369036417543
# PRECiSE_CO96: 1.59183322288982
# PRECiSE_A_CO96: 1.0511401849221025
# Warning: exp-results/beta1,3_wor0_lower_ci.pkl already exists!
# HR: 0.7330076783562853
# PRECiSE_CO96: 1.4126373269570505
# PRECiSE_A_CO96: 1.0222290535586114
# PRECiSE_R70: 1.2961667672107535
# UP: 1.614974542652091
# LBUP1: 0.7406017959715212
# LBUP2: 0.8685515827925263
# LBUP3: 0.8594181703044399
# HybridUP1,50: 0.7394189598210097
# HybridUP2,50: 0.8464976340669791
# HybridUP3,50: 0.8479099579964906
# UP_ones: 1.7687522081558296
# Warning: exp-results/beta10,30_wor0_lower_ci.pkl already exists!
# HR: 0.7926216826004787
# PRECiSE_CO96: 1.6246261756006668
# PRECiSE_A_CO96: 1.010931542983125
# PRECiSE_R70: 1.5695128735452115
# UP: 1.4781981304603948
# LBUP1: 0.7186039005827832
# LBUP2: 0.7785594763858001
# LBUP3: 0.7859510656540534
# HybridUP1,50: 0.8045086287676033
# HybridUP2,50: 0.7816887274237616
# HybridUP3,50: 0.7911312096781943
# UP_ones: 1.613941123056406
# Warning: exp-results/bern0.5_wor0_lower_ci.pkl already exists!
# HR: 0.8622245221403922
# PRECiSE_CO96: 1.5397241298277737
# PRECiSE_A_CO96: 1.0560723265439056
# Warning: exp-results/beta1,1_wor0_lower_ci.pkl already exists!
# HR: 0.8093705469829567
# PRECiSE_CO96: 1.7618193483790663
# PRECiSE_A_CO96: 1.0021255009062542
# PRECiSE_R70: 1.534471117903047
# UP: 1.6019299974770085
# LBUP1: 0.8683511220151561
# LBUP2: 1.0666704522027648
# LBUP3: 1.0612148824877876
# HybridUP1,50: 0.8908200777462607
# HybridUP2,50: 1.0300455172253944
# HybridUP3,50: 1.010760332423664
# UP_ones: 1.8137901771587301
# Warning: exp-results/beta10,10_wor0_lower_ci.pkl already exists!
# HR: 0.7548750088434348
# PRECiSE_CO96: 1.452470686315258
# PRECiSE_A_CO96: 1.0142425057113749
# PRECiSE_R70: 1.3560927130799167
# UP: 1.5731173538502925
# LBUP1: 0.7200806110014016
# LBUP2: 0.9001052609319551
# LBUP3: 0.8763143659122117
# HybridUP1,50: 0.726373361895776
# HybridUP2,50: 0.7537020158528352
# HybridUP3,50: 0.8462927914057703
# UP_ones: 1.6638380137293798
